# %% [markdown]
# concatenation_fucation

# %%
frist_name =str(input("Enter your frist name"))
last_name = str(input("Enter your last name"))
full_name = frist_name +" "+ last_name
r=10
print(f"{"="*r}\n {full_name}\n {"="*r}")
# Out:
# Enter your frist name varun
# Enter your last name kumar
# ...
#  varun kumar
# ...

# %% [markdown]
# repetition_fucation

# %%
name =str(input(" Enter your frist name "))
number = int(input("enter the number to mult"))
#name+=" "
mult  = (name + " ")*number
print(mult)
# Out:
#  Enter your frist name  varun
# enter the number to mult 9
# varun varun varun varun varun varun varun varun varun

# %%
len_fucation

# %%
name =str(input("Enter your frist name"))
length =len(name)
print(length )
# Out:
# Enter your frist name varun
# 5

# %% [markdown]
# indexing

# %%
name = "varun"
indexing = name[1]
print(indexing)
# Out:
# a

# %%
name = "varun"
slicing = name[0:3]
print(slicing)
# Out:
# var

# %%
name ="Varun Kumar"
slicing = name[0:10:2]
print(slicing)
# Out:
# VrnKm

# %% [markdown]
# Lower , upper ,capitalize

# %%
name = input("enter the name::")
lower = name.lower()
upper = name.upper()
capitalize = name.capitalize()
print(f"{lower}\n{upper}\n{capitalize}")
# Out:
# enter the name VArun Kumar
# varun kumar
# VARUN KUMAR
# Varun kumar

# %% [markdown]
# strips,lstrip,r strip

# %%
name = " Varun "
strip = name.strip(" ")
print(strip)
# Out:
# Varun

# %%
name = "    Varun "
strip = name.lstrip(" ")
print(strip)
# Out:
# Varun

# %%
name = "Varun           "
strip = name.rstrip(" ")
print(strip)
# Out:
# Varun

# %% [markdown]
# #Replace

# %%
name = "Var un"
result = name.replace(" ", "")
print(result)
# Out:
# Varun

# %%
name = "Varun"
result = name.replace("Varun", "Kumar")
print(result)
# Out:
# Kumar

# %% [markdown]
# split : is used to convert the string to list

# %%
name = "varun kumar is good"
split = name.split()
print(split)
# Out:
# ['varunkumaris', 'good']

# %%
litr = ("varun", "vilas", "arvind", "manoj")
join = "_".join(litr)

print(join)
# Out:
# varun_vilas_arvind_manoj

# %% [markdown]
# startswith

# %%
name= ("varun")
check = input("check which letter you need to find")
swith = name.startswith(check)
print(swith)
# Out:
# check which letter you need to find var
# True

# %%
name= ("varun")
check = input("check which letter you need to find")
swith = name.endswith(check)
print(swith)
# Out:
# check which letter you need to find un
# True

# %% [markdown]
# find,index

# %%
litr = ("varun")
finding = litr.find("n")
print(finding)
# Out:
# 4

# %%
litr = "varun  aruns"
indexing = litr.index("s")
print(indexing)
# Out:
# 11
